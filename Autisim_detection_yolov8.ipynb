# %%
# !nvidia-smi
# Out:
# Sat Mar 16 15:45:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # New Section

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display

import ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 46.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 72.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 47.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !mkdir /content/drive/MyDrive/Autisim

# %%
import zipfile

# Path to the .zip file
zip_file_path = '/content/drive/MyDrive/autism.v3i.yolov8.zip'

# Destination folder to extract the contents of the .zip file
destination_folder = '/content/drive/MyDrive/Autisim'

# Extract the contents of the .zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_folder)

# %%
cd /content
# Out:
# /content

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
#!pip install roboflow

#from roboflow import Roboflow
#rf = Roboflow(api_key="yq77RtORFXmFWdoqtWgZ")
#project = rf.workspace("detection-ifxlr").project("autism-7ywpu")
#version = project.version(3)
#dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.29, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to autism-3 in yolov8:: 100%|██████████| 28716/28716 [04:15<00:00, 112.51it/s]

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/drive/MyDrive/Autisim/train/images/*.jpg')[:15]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
pwd
# Out:
# '/content'

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/Autisim/data.yaml epochs=2 imgsz=640
# Out:
# /content
# ...
# 100% 49.7M/49.7M [00:00<00:00, 217MB/s]
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/Autisim/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/Autisim/valid/labels.cache... 1688 images, 19 backgrounds, 0 corrupt: 100% 1688/1688 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 106/106 [00:50<00:00,  2.11it/s]
#                    all       1688       1669      0.684      0.812      0.786      0.747
#               Autistic       1688        775      0.609      0.902      0.755      0.697
#           Non_Autistic       1688        894      0.759      0.721      0.818      0.797
# Speed: 0.3ms preprocess, 16.3ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# %cd {HOME}
# !yolo task=detect mode=predict  model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Autisim/test/images
# Out:
# /content
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/844 /content/drive/MyDrive/Autisim/test/images/0003-Copy-2-_jpg.rf.75c74765c026a37aa664e85b8cf7fc93.jpg: 576x640 1 Autistic, 1 Non_Autistic, 105.4ms
# image 2/844 /content/drive/MyDrive/Autisim/test/images/0006-Copy-2-_jpg.rf.b786afc195538aeb4064f7e79b25bce5.jpg: 640x608 1 Autistic, 71.3ms
# image 3/844 /content/drive/MyDrive/Autisim/test/images/0007-Copy-2-_jpg.rf.3b3bea7c99f56be4a424585bc3b8ef1d.jpg: 512x640 1 Autistic, 70.5ms
# image 4/844 /content/drive/MyDrive/Autisim/test/images/0013-Copy-2-_jpg.rf.779d753d172b9b2471619c79bb192fdc.jpg: 544x640 1 Autistic, 83.4ms
# image 5/844 /content/drive/MyDrive/Autisim/test/images/0023-Copy-3-_jpg.rf.dd89e6b6110ccaa0350849a34e2a8326.jpg: 480x640 1 Non_Autistic, 73.1ms
# ...

# %%
Image(filename='/content/runs/detect/train/F1_curve.png',width=800)

# %%
Image(filename='/content/runs/detect/train/PR_curve.png',width=800)

# %%
Image(filename='/content/runs/detect/train/P_curve.png',width=800)

# %%
Image(filename='/content/runs/detect/train/R_curve.png',width=800)

# %%
Image(filename='/content/runs/detect/train/confusion_matrix.png',width=800)

# %%
Image(filename='/content/runs/detect/train/results.png',width=800)

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:15]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
Image(filename='/content/runs/detect/train/train_batch1.jpg',width=600)

# %%
Image(filename='/content/runs/detect/train/val_batch0_pred.jpg',width=800)
